# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.offline as pyo
import kaleido
# Out:
# /home/elina/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# # KModes

# %%
df_ite_kmode_cao = pd.read_csv('clustering_result/df_ite_kmodes_range.csv')
pd.set_option('display.max_columns', None)
df_ite_kmode_cao.head()
# Out:
#    11  12   13   14   15   16   17   18  Female  Male   QN6   QN7   QN8   QN9  \
# 0  21  59  430  499  568  524  465  668    1933  1301  3513  5512  5894  4662
# 1  11   5   89  105  197  210  239  441     423   874  1466  2193  2358  2000
#
#    QN10  QN11  QN12  QN13  QN14  QN15  QN16  QN17    QN18    QN19  QN20  \
# 0  3744  3546  3360  3397  3557  4208  4020  4591  3854.0  3778.0  4438
# 1  1606  1461  1372  1400  1447  2111  2013  2333  1826.5  1782.0  2220
#
#      QN21  QN22  QN23  QN24  QN25  QN26  QN27    QN28  QN29  QN30    QN31  \
# 0  3835.5  3658  3634  3798  3994  3962  3678  3656.0  3355  3347  3377.0
# 1  1791.0  1562  1588  1630  1748  1796  1422  1727.0  1614  1510  1545.5
#
#    QN32  QN33    QN34  QN35    QN36    QN37  QN38  QN39    QN40  QN41  QN42  \
# 0  4751  3668  4271.5  3807  3660.0  3646.5  3735  3434  3491.5  3339  3309
# 1  2286  1594  2168.0  2191  1939.5  1904.5  2108  1699  1660.0  1510  1458
#
# ...

# %%
df_ite_kmode_cao.loc[0] = df_ite_kmode_cao.iloc[0]/3234
df_ite_kmode_cao.loc[1] = df_ite_kmode_cao.iloc[1]/1297
df_ite_kmode_cao
# Out:
#          11        12        13        14        15        16        17  \
# 0  0.006494  0.018244  0.132962  0.154298  0.175634  0.162028  0.143785
# 1  0.008481  0.003855  0.068620  0.080956  0.151889  0.161912  0.184271
#
#          18    Female      Male       QN6       QN7       QN8       QN9  \
# 0  0.206555  0.597712  0.402288  1.086271  1.704391  1.822511  1.441558
# 1  0.340015  0.326137  0.673863  1.130301  1.690825  1.818042  1.542020
#
#        QN10      QN11      QN12      QN13      QN14      QN15      QN16  \
# 0  1.157699  1.096475  1.038961  1.050402  1.099876  1.301175  1.243043
# 1  1.238242  1.126446  1.057826  1.079414  1.115652  1.627602  1.552043
#
#        QN17      QN18      QN19      QN20      QN21      QN22      QN23  \
# 0  1.419604  1.191713  1.168213  1.372294  1.185993  1.131107  1.123686
# 1  1.798766  1.408250  1.373940  1.711642  1.380879  1.204318  1.224364
#
#        QN24      QN25      QN26      QN27      QN28      QN29      QN30  \
# ...

# %%
df_ite_kmode_cao.loc[0] = df_ite_kmode_cao.iloc[0]/3234
df_ite_kmode_cao.loc[1] = df_ite_kmode_cao.iloc[1]/1297
df_ite_kmode_cao
# Out:
#          11        12        13        14        15        16        17  \
# 0  0.000002  0.000006  0.000041  0.000048  0.000054  0.000050  0.000044
# 1  0.000007  0.000003  0.000053  0.000062  0.000117  0.000125  0.000142
#
#          18    Female      Male       QN6       QN7       QN8       QN9  \
# 0  0.000064  0.000185  0.000124  0.000336  0.000527  0.000564  0.000446
# 1  0.000262  0.000251  0.000520  0.000871  0.001304  0.001402  0.001189
#
#        QN10      QN11      QN12      QN13     QN14      QN15      QN16  \
# 0  0.000358  0.000339  0.000321  0.000325  0.00034  0.000402  0.000384
# 1  0.000955  0.000869  0.000816  0.000832  0.00086  0.001255  0.001197
#
#        QN17      QN18      QN19      QN20      QN21      QN22      QN23  \
# 0  0.000439  0.000368  0.000361  0.000424  0.000367  0.000350  0.000347
# 1  0.001387  0.001086  0.001059  0.001320  0.001065  0.000929  0.000944
#
#        QN24      QN25      QN26      QN27      QN28      QN29      QN30  \
# ...

# %%
df_mca_kmode_cao = pd.read_csv('clustering_result/df_mca_kmodes.csv')
pd.set_option('display.max_columns', None)
df_mca_kmode_cao.head()
# Out:
#    11  12   13   14   15   16   17   18  Female  Male   QN6   QN7   QN8   QN9  \
# 0  19  59  436  506  578  513  465  665    1978  1263  3527  5522  5905  4676
# 1  13   5   86  102  186  208  231  459     411   879  1453  2181  2344  1986
#
#    QN10  QN11  QN12  QN13  QN14  QN15  QN16  QN17    QN18    QN19  QN20  \
# 0  3753  3556  3372  3406  3561  4230  4025  4639  3851.0  3790.0  4458
# 1  1598  1451  1360  1392  1448  2085  2007  2305  1791.5  1756.0  2195
#
#      QN21  QN22  QN23  QN24  QN25  QN26  QN27    QN28  QN29  QN30    QN31  \
# 0  3816.0  3666  3644  3803  3998  3971  3682  3649.0  3356  3355  3376.0
# 1  1761.0  1555  1581  1627  1739  1784  1418  1714.0  1611  1502  1540.0
#
#    QN32  QN33    QN34  QN35    QN36    QN37  QN38  QN39    QN40  QN41  QN42  \
# 0  4766  3677  4201.0  3806  3660.5  3631.5  3729  3445  3482.5  3337  3308
# 1  2269  1586  2164.5  2188  1931.0  1897.5  2116  1693  1646.0  1510  1456
#
# ...

# %%
df_mca_kmode_cao.loc[0] = df_mca_kmode_cao.iloc[0]/3241
df_mca_kmode_cao.loc[1] = df_mca_kmode_cao.iloc[1]/1290
df_mca_kmode_cao
# Out:
#          11        12        13        14        15        16        17  \
# 0  0.005862  0.018204  0.134526  0.156125  0.178340  0.158284  0.143474
# 1  0.010078  0.003876  0.066667  0.079070  0.144186  0.161240  0.179070
#
#          18    Female      Male       QN6       QN7       QN8       QN9  \
# 0  0.205184  0.610305  0.389695  1.088244  1.703795  1.821969  1.442765
# 1  0.355814  0.318605  0.681395  1.126357  1.690698  1.817054  1.539535
#
#        QN10      QN11      QN12     QN13      QN14      QN15      QN16  \
# 0  1.157976  1.097192  1.040420  1.05091  1.098735  1.305153  1.241901
# 1  1.238760  1.124806  1.054264  1.07907  1.122481  1.616279  1.555814
#
#        QN17      QN18      QN19      QN20      QN21      QN22      QN23  \
# 0  1.431348  1.188214  1.169392  1.375501  1.177414  1.131132  1.124344
# 1  1.786822  1.388760  1.361240  1.701550  1.365116  1.205426  1.225581
#
#        QN24      QN25      QN26      QN27      QN28      QN29      QN30  \
# ...

# %%
df_mf_kmode_cao = pd.read_csv('clustering_result/df_mf_kmodes.csv')
pd.set_option('display.max_columns', None)
df_mf_kmode_cao.head()
# Out:
#    11  12   13   14   15   16   17   18  Female  Male   QN6   QN7   QN8   QN9  \
# 0  20  61  440  514  567  531  480  714    1994  1333  3621  5678  6066  4795
# 1  12   5   88  100  186  190  216  407     390   814  1360  2025  2180  1875
#
#    QN10  QN11  QN12  QN13  QN14  QN15  QN16  QN17    QN18    QN19  QN20  \
# 0  3851  3645  3456  3496  3661  4367  4156  4684  3953.5  3892.5  4507
# 1  1501  1364  1276  1301  1346  1954  1878  2118  1670.5  1633.0  1994
#
#      QN21  QN22  QN23  QN24  QN25  QN26  QN27    QN28  QN29  QN30    QN31  \
# 0  3923.0  3765  3746  3922  4129  4096  3768  3760.0  3449  3443  3474.5
# 1  1624.5  1456  1483  1532  1621  1662  1332  1625.5  1525  1418  1463.5
#
#    QN32  QN33    QN34  QN35    QN36    QN37  QN38  QN39    QN40  QN41  QN42  \
# 0  4917  3785  4360.0  3937  3770.0  3767.0  3861  3544  3594.5  3425  3394
# 1  2120  1484  2038.5  2060  1825.5  1785.5  2005  1603  1556.0  1430  1378
#
# ...

# %%
df_mf_kmode_cao.loc[0] = df_mf_kmode_cao.iloc[0]/3327
df_mf_kmode_cao.loc[1] = df_mf_kmode_cao.iloc[1]/1204
df_mf_kmode_cao
# Out:
#          11        12        13        14        15        16        17  \
# 0  0.006011  0.018335  0.132251  0.154494  0.170424  0.159603  0.144274
# 1  0.009967  0.004153  0.073090  0.083056  0.154485  0.157807  0.179402
#
#          18    Female      Male       QN6       QN7       QN8       QN9  \
# 0  0.214608  0.599339  0.400661  1.088368  1.706643  1.823264  1.441238
# 1  0.338040  0.323920  0.676080  1.129568  1.681894  1.810631  1.557309
#
#        QN10      QN11      QN12      QN13      QN14      QN15      QN16  \
# 0  1.157499  1.095582  1.038774  1.050797  1.100391  1.312594  1.249173
# 1  1.246678  1.132890  1.059801  1.080565  1.117940  1.622924  1.559801
#
#        QN17      QN18      QN19      QN20      QN21      QN22      QN23  \
# 0  1.407875  1.188308  1.169973  1.354674  1.179140  1.131650  1.125939
# 1  1.759136  1.387458  1.356312  1.656146  1.349252  1.209302  1.231728
#
#        QN24      QN25      QN26      QN27      QN28      QN29      QN30  \
# ...

# %% [markdown]
# # KMeans

# %%
df_ite_kMeans_2 = pd.read_csv('clustering_result/result_ite_kmeans_2.csv')
df_ite_kMeans_2.head()
# Out:
#    11  12   13   14   15   16   17   18  Female  Male  dietary  hygiene  \
# 0  17  57  409  454  524  416  361  412    1659   991   3833.4   2828.5
# 1  15   7  110  150  241  318  343  697     697  1184   2756.2   2056.5
#
#         injury  mental_health  tobacco_use  alcohol_use  drug_use  \
# 0  3475.428571    3104.166667  3020.333333  3071.666667  2732.625
# 1  2639.000000    2307.500000  2384.750000  2689.000000  2152.500
#
#    sexual_behaviours  physical_activity  protective_factors
# 0             2799.4            4226.75         3944.166667
# 1             3184.9            2955.00         2917.666667

# %%
df_ite_kMeans_2.loc[0] = df_ite_kMeans_2.iloc[0]/2650
df_ite_kMeans_2.loc[1] = df_ite_kMeans_2.iloc[1]/1881
df_ite_kMeans_2
# Out:
#          11        12       13        14        15        16        17  \
# 0  0.006415  0.021509  0.15434  0.171321  0.197736  0.156981  0.136226
# 1  0.007974  0.003721  0.05848  0.079745  0.128123  0.169059  0.182350
#
#          18    Female      Male   dietary   hygiene    injury  mental_health  \
# 0  0.155472  0.626038  0.373962  1.446566  1.067358  1.311482       1.171384
# 1  0.370548  0.370548  0.629452  1.465284  1.093301  1.402977       1.226741
#
#    tobacco_use  alcohol_use  drug_use  sexual_behaviours  physical_activity  \
# 0     1.139748     1.159119  1.031179           1.056377           1.595000
# 1     1.267810     1.429559  1.144338           1.693195           1.570973
#
#    protective_factors
# 0            1.488365
# 1            1.551125

# %%
categories = ['dietary_behaviours','hygiene','injury','mental_health','tobacco_use','alcohol_use','drug_use','sexual_behaviours','physical_activity','protective_factors']
categories = [*categories, categories[0]]

cluster_1 = [1.47,1.09,1.40,1.23,1.27,1.43,1.14,1.69,1.57,1.55]
cluster_2 = [1.45,1.07,1.31,1.17,1.14,1.16,1.03,1.06,1.60,1.49]
cluster_1 = [*cluster_1, cluster_1[0]]
cluster_2 = [*cluster_2, cluster_2[0]]



fig = go.Figure(
    data=[
        go.Scatterpolar(r=cluster_1, theta=categories, name='cluster 1'),
        go.Scatterpolar(r=cluster_2, theta=categories, name='cluster 2')
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Result of Kmeans with number 2 on ite'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig)
fig.write_image("radar_chart_Kmeans_ite_2.jpg")

# %%
df_ite_kMeans_6 = pd.read_csv('clustering_result/result_ite_kmeans_6.csv')
df_ite_kMeans_6.head(6)
# Out:
#    11  12   13   14   15   16   17   18  Female  Male  dietary  hygiene  \
# 0   5   3   21   24   53   49   38   79      90   182    408.6   330.25
# 1   7  38  217  217  237  172  133  176     790   407   1722.2  1270.50
# 2   7   3   63   84  117  149  171  324     416   502   1327.2   988.00
# 3   8  11  122  143  158  130  105   84     453   308   1118.2   825.25
# 4   3   1   29   45   84  135  154  339     258   532   1158.4   841.00
# 5   2   8   67   91  116   99  103  107     349   244    855.0   630.00
#
#         injury  mental_health  tobacco_use  alcohol_use  drug_use  \
# 0   429.642857     372.500000   434.416667   451.083333   476.125
# 1  1372.785714    1325.166667  1312.000000  1253.666667  1209.875
# 2  1186.000000    1082.833333  1035.500000  1009.500000   939.250
# 3  1230.357143     996.500000   880.500000   808.833333   782.250
# 4  1106.500000     947.166667  1005.583333  1301.083333   845.375
# ...

# %%
df_ite_kMeans_6.loc[0] = df_ite_kMeans_6.iloc[0]/272
df_ite_kMeans_6.loc[1] = df_ite_kMeans_6.iloc[1]/1197
df_ite_kMeans_6.loc[2] = df_ite_kMeans_6.iloc[2]/918
df_ite_kMeans_6.loc[3] = df_ite_kMeans_6.iloc[3]/761
df_ite_kMeans_6.loc[4] = df_ite_kMeans_6.iloc[4]/790
df_ite_kMeans_6.loc[5] = df_ite_kMeans_6.iloc[5]/593
df_ite_kMeans_6.head(6)
# Out:
#          11        12        13        14        15        16        17  \
# 0  0.018382  0.011029  0.077206  0.088235  0.194853  0.180147  0.139706
# 1  0.005848  0.031746  0.181287  0.181287  0.197995  0.143693  0.111111
# 2  0.007625  0.003268  0.068627  0.091503  0.127451  0.162309  0.186275
# 3  0.010512  0.014455  0.160315  0.187911  0.207622  0.170828  0.137976
# 4  0.003797  0.001266  0.036709  0.056962  0.106329  0.170886  0.194937
# 5  0.003373  0.013491  0.112985  0.153457  0.195616  0.166948  0.173693
#
#          18    Female      Male   dietary   hygiene    injury  mental_health  \
# 0  0.290441  0.330882  0.669118  1.502206  1.214154  1.579569       1.369485
# 1  0.147034  0.659983  0.340017  1.438764  1.061404  1.146855       1.107073
# 2  0.352941  0.453159  0.546841  1.445752  1.076253  1.291939       1.179557
# 3  0.110381  0.595269  0.404731  1.469382  1.084428  1.616764       1.309461
# 4  0.429114  0.326582  0.673418  1.466329  1.064557  1.400633       1.198945
# ...

# %%
categories = ['dietary_behaviours','hygiene','injury','mental_health','tobacco_use','alcohol_use','drug_use','sexual_behaviours','physical_activity','protective_factors']
categories = [*categories, categories[0]]

cluster_1 = [1.44,1.06,1.15,1.11,1.10,1.05,1.01,1.03,1.60,1.46]
cluster_2 = [1.47,1.08,1.62,1.31,1.16,1.06,1.03,1.07,1.58,1.51]
cluster_3 = [1.44,1.06,1.33,1.16,1.24,1.58,1.07,1.02,1.59,1.53]
cluster_4 = [1.45,1.08,1.29,1.18,1.13,1.10,1.02,1.68,1.58,1.51]
cluster_5 = [1.50,1.21,1.58,1.37,1.60,1.66,1.75,1.58,1.57,1.60]
cluster_6 = [1.47,1.06,1.40,1.20,1.27,1.65,1.07,1.73,1.57,1.56]
cluster_1 = [*cluster_1, cluster_1[0]]
cluster_2 = [*cluster_2, cluster_2[0]]
cluster_3 = [*cluster_3, cluster_3[0]]
cluster_4 = [*cluster_4, cluster_4[0]]
cluster_5 = [*cluster_5, cluster_5[0]]
cluster_6 = [*cluster_6, cluster_6[0]]



fig = go.Figure(
    data=[
        go.Scatterpolar(r=cluster_1, theta=categories, name='cluster 1'),
        go.Scatterpolar(r=cluster_2, theta=categories, name='cluster 2'),
        go.Scatterpolar(r=cluster_3, theta=categories, name='cluster 3'),
        go.Scatterpolar(r=cluster_4, theta=categories, name='cluster 4'),
        go.Scatterpolar(r=cluster_5, theta=categories, name='cluster 5'),
        go.Scatterpolar(r=cluster_6, theta=categories, name='cluster 6'),
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Result of Kmeans with number 6 on ite'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig)
fig.write_image("radar_chart_Kmeans_ite_6.jpg")

# %%
df_mca_kMeans_2 = pd.read_csv('clustering_result/result_mca_kmeans_2.csv')
df_mca_kMeans_2.head()
# Out:
#    11  12   13   14   15   16   17   18  Female  Male  dietary  hygiene  \
# 0  17   7  107  140  229  304  325  709     677  1161   2692.2   2011.0
# 1  15  57  415  468  535  417  371  415    1712   981   3896.8   2875.5
#
#         injury  mental_health  tobacco_use  alcohol_use  drug_use  \
# 0  2566.785714    2253.333333  2329.083333  2631.666667  2099.125
# 1  3534.571429    3158.000000  3071.083333  3112.166667  2778.500
#
#    sexual_behaviours  physical_activity  protective_factors
# 0             3133.3            2889.75         2850.000000
# 1             2842.8            4291.25         4010.833333

# %%
df_mca_kMeans_2.loc[0] = df_mca_kMeans_2.iloc[0]/1838
df_mca_kMeans_2.loc[1] = df_mca_kMeans_2.iloc[1]/2693
df_mca_kMeans_2
# Out:
#          11        12        13        14        15        16        17  \
# 0  0.009249  0.003808  0.058215  0.076170  0.124592  0.165397  0.176823
# 1  0.005570  0.021166  0.154103  0.173784  0.198663  0.154846  0.137765
#
#          18    Female      Male   dietary   hygiene    injury  mental_health  \
# 0  0.385745  0.368335  0.631665  1.464744  1.094124  1.396510        1.22597
# 1  0.154103  0.635722  0.364278  1.447011  1.067768  1.312503        1.17267
#
#    tobacco_use  alcohol_use  drug_use  sexual_behaviours  physical_activity  \
# 0     1.267184      1.43181  1.142070           1.704733           1.572225
# 1     1.140395      1.15565  1.031749           1.055626           1.593483
#
#    protective_factors
# 0            1.550598
# 1            1.489355

# %%
categories = ['dietary_behaviours','hygiene','injury','mental_health','tobacco_use','alcohol_use','drug_use','sexual_behaviours','physical_activity','protective_factors']
categories = [*categories, categories[0]]

cluster_1 = [1.46,1.09,1.40,1.23,1.27,1.43,1.14,1.70,1.57,1.55]
cluster_2 = [1.45,1.07,1.31,1.17,1.14,1.16,1.03,1.06,1.59,1.49]
cluster_1 = [*cluster_1, cluster_1[0]]
cluster_2 = [*cluster_2, cluster_2[0]]


 
fig = go.Figure(
    data=[
        go.Scatterpolar(r=cluster_1, theta=categories, name='cluster 1'),
        go.Scatterpolar(r=cluster_2, theta=categories, name='cluster 2')
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Result of Kmeans with number 2 on mca'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig)
fig.write_image("radar_chart_Kmeans_mca_2.jpg")

# %%
df_mca_kMeans_6 = pd.read_csv('clustering_result/result_mca_kmeans_6.csv')
df_mca_kMeans_6.head(6)
# Out:
#    11  12   13   14   15   16   17   18  Female  Male  dietary  hygiene  \
# 0   9   3   62   81  111  137  162  318     400   483   1277.8   951.00
# 1   6  12  124  141  162  125  103   80     467   286   1104.4   818.00
# 2   6  37  215  221  234  174  138  177     802   400   1726.4  1276.25
# 3   3   1   30   46   82  133  150  360     260   545   1181.2   860.50
# 4   2   8   70   96  122  101  105  110     370   244    888.4   651.00
# 5   6   3   21   23   53   51   38   79      90   184    410.8   329.75
#
#         injury  mental_health  tobacco_use  alcohol_use  drug_use  \
# 0  1146.428571    1039.000000   997.333333   958.166667   902.500
# 1  1207.357143     986.833333   866.000000   785.416667   773.125
# 2  1376.428571    1328.833333  1317.333333  1253.166667  1214.750
# 3  1119.142857     965.833333  1015.666667  1321.250000   857.875
# 4   820.642857     713.000000   763.500000   966.333333   651.375
# ...

# %%
df_mca_kMeans_6.loc[0] = df_mca_kMeans_6.iloc[0]/883
df_mca_kMeans_6.loc[1] = df_mca_kMeans_6.iloc[1]/753
df_mca_kMeans_6.loc[2] = df_mca_kMeans_6.iloc[2]/1202
df_mca_kMeans_6.loc[3] = df_mca_kMeans_6.iloc[3]/805
df_mca_kMeans_6.loc[4] = df_mca_kMeans_6.iloc[4]/614
df_mca_kMeans_6.loc[5] = df_mca_kMeans_6.iloc[5]/274
df_mca_kMeans_6.head(6)
# Out:
#          11        12        13        14        15        16        17  \
# 0  0.010193  0.003398  0.070215  0.091733  0.125708  0.155153  0.183465
# 1  0.007968  0.015936  0.164675  0.187251  0.215139  0.166003  0.136786
# 2  0.004992  0.030782  0.178869  0.183860  0.194676  0.144759  0.114809
# 3  0.003727  0.001242  0.037267  0.057143  0.101863  0.165217  0.186335
# 4  0.003257  0.013029  0.114007  0.156352  0.198697  0.164495  0.171010
# 5  0.021898  0.010949  0.076642  0.083942  0.193431  0.186131  0.138686
#
#          18    Female      Male   dietary   hygiene    injury  mental_health  \
# 0  0.360136  0.453001  0.546999  1.447112  1.077010  1.298334       1.176670
# 1  0.106242  0.620186  0.379814  1.466667  1.086321  1.603396       1.310536
# 2  0.147255  0.667221  0.332779  1.436273  1.061772  1.145115       1.105519
# 3  0.447205  0.322981  0.677019  1.467329  1.068944  1.390240       1.199793
# 4  0.179153  0.602606  0.397394  1.446906  1.060261  1.336552       1.161238
# ...

# %%
categories = ['dietary_behaviours','hygiene','injury','mental_health','tobacco_use','alcohol_use','drug_use','sexual_behaviours','physical_activity','protective_factors']
categories = [*categories, categories[0]]

cluster_1 = [1.44,1.06,1.15,1.11,1.10,1.04,1.01,1.02,1.60,1.47]
cluster_2 = [1.47,1.09,1.60,1.31,1.15,1.04,1.03,1.06,1.58,1.51]
cluster_3 = [1.45,1.06,1.34,1.16,1.24,1.57,1.06,1.02,1.59,1.53]
cluster_4 = [1.50,1.20,1.57,1.38,1.61,1.68,1.74,1.58,1.58,1.60]
cluster_5 = [1.45,1.08,1.30,1.18,1.13,1.09,1.02,1.69,1.58,1.51]
cluster_6 = [1.47,1.07,1.39,1.20,1.26,1.64,1.07,1.74,1.57,1.56]
cluster_1 = [*cluster_1, cluster_1[0]]
cluster_2 = [*cluster_2, cluster_2[0]]
cluster_3 = [*cluster_3, cluster_3[0]]
cluster_4 = [*cluster_4, cluster_4[0]]
cluster_5 = [*cluster_5, cluster_5[0]]
cluster_6 = [*cluster_6, cluster_6[0]]



fig = go.Figure(
    data=[
        go.Scatterpolar(r=cluster_1, theta=categories, name='cluster 1'),
        go.Scatterpolar(r=cluster_2, theta=categories, name='cluster 2'),
        go.Scatterpolar(r=cluster_3, theta=categories, name='cluster 3'),
        go.Scatterpolar(r=cluster_4, theta=categories, name='cluster 4'),
        go.Scatterpolar(r=cluster_5, theta=categories, name='cluster 5'),
        go.Scatterpolar(r=cluster_6, theta=categories, name='cluster 6'),
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Result of Kmeans with number 6 on mca'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig)
fig.write_image("radar_chart_Kmeans_mca_6.jpg")

# %%
df_mf_kMeans_2 = pd.read_csv('clustering_result/result_mf_kmeans_2.csv')
df_mf_kMeans_2.head()
# Out:
#    11  12   13   14   15   16   17   18  Female  Male  dietary  hygiene  \
# 0  16   6  110  145  234  294  324  669     687  1111   2631.2  1962.75
# 1  16  60  418  469  519  427  372  452    1697  1036   3959.2  2923.50
#
#         injury  mental_health  tobacco_use  alcohol_use  drug_use  \
# 0  2473.428571    2200.166667      2275.00  2555.750000  2055.875
# 1  3577.285714    3218.500000      3135.75  3203.666667  2833.000
#
#    sexual_behaviours  physical_activity  protective_factors
# 0             3062.7            2823.25         2782.833333
# 1             2847.5            4356.00         4078.500000

# %%
df_mf_kMeans_2.loc[0] = df_mf_kMeans_2.iloc[0]/1798
df_mf_kMeans_2.loc[1] = df_mf_kMeans_2.iloc[1]/2733
df_mf_kMeans_2
# Out:
#          11        12        13        14        15        16        17  \
# 0  0.008899  0.003337  0.061179  0.080645  0.130145  0.163515  0.180200
# 1  0.005854  0.021954  0.152945  0.171606  0.189901  0.156239  0.136114
#
#          18    Female      Male   dietary   hygiene    injury  mental_health  \
# 0  0.372080  0.382091  0.617909  1.463404  1.091630  1.375655       1.223674
# 1  0.165386  0.620929  0.379071  1.448664  1.069704  1.308923       1.177644
#
#    tobacco_use  alcohol_use  drug_use  sexual_behaviours  physical_activity  \
# 0     1.265295     1.421440  1.143423           1.703393           1.570217
# 1     1.147366     1.172216  1.036590           1.041895           1.593853
#
#    protective_factors
# 0            1.547738
# 1            1.492316

# %%
categories = ['dietary_behaviours','hygiene','injury','mental_health','tobacco_use','alcohol_use','drug_use','sexual_behaviours','physical_activity','protective_factors']
categories = [*categories, categories[0]]

cluster_1 = [1.46,1.09,1.38,1.22,1.27,1.42,1.14,1.70,1.57,1.55]
cluster_2 = [1.45,1.07,1.31,1.18,1.15,1.17,1.04,1.04,1.59,1.49]
cluster_1 = [*cluster_1, cluster_1[0]]
cluster_2 = [*cluster_2, cluster_2[0]]



fig = go.Figure(
    data=[
        go.Scatterpolar(r=cluster_1, theta=categories, name='cluster 1'),
        go.Scatterpolar(r=cluster_2, theta=categories, name='cluster 2')
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Result of Kmeans with number 2 on mf'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig)
fig.write_image("radar_chart_Kmeans_mf_2.jpg")

# %%
df_mf_kMeans_6 = pd.read_csv('clustering_result/result_mf_kmeans_6.csv')
df_mf_kMeans_6.head(6)
# Out:
#    11  12   13   14   15   16   17   18  Female  Male  dietary  hygiene  \
# 0   4  11  117  132  150  123   98   88     438   285   1063.8   781.50
# 1   3   1   30   45   86  127  144  334     258   512   1131.2   823.25
# 2   2   8   73  100  123  115  112  136     388   281    967.8   710.75
# 3   6   3   23   24   52   49   42   77      91   185    414.2   333.75
# 4   8   3   62   86  113  137  160  299     403   465   1253.6   932.50
# 5   9  40  223  227  229  170  140  187     806   419   1759.8  1304.50
#
#         injury  mental_health  tobacco_use  alcohol_use  drug_use  \
# 0  1154.428571     955.500000   837.083333   758.333333   742.500
# 1  1057.714286     922.166667   974.583333  1266.000000   823.750
# 2   889.357143     778.500000   832.500000  1052.583333   712.000
# 3   432.857143     381.500000   447.500000   463.416667   486.875
# 4  1114.785714    1023.000000   977.750000   941.500000   886.250
# ...

# %%
df_mf_kMeans_6.loc[0] = df_mf_kMeans_6.iloc[0]/723
df_mf_kMeans_6.loc[1] = df_mf_kMeans_6.iloc[1]/770
df_mf_kMeans_6.loc[2] = df_mf_kMeans_6.iloc[2]/669
df_mf_kMeans_6.loc[3] = df_mf_kMeans_6.iloc[3]/276
df_mf_kMeans_6.loc[4] = df_mf_kMeans_6.iloc[4]/868
df_mf_kMeans_6.loc[5] = df_mf_kMeans_6.iloc[5]/1225
df_mf_kMeans_6.head(6)
# Out:
#          11        12        13        14        15        16        17  \
# 0  0.005533  0.015214  0.161826  0.182573  0.207469  0.170124  0.135546
# 1  0.003896  0.001299  0.038961  0.058442  0.111688  0.164935  0.187013
# 2  0.002990  0.011958  0.109118  0.149477  0.183857  0.171898  0.167414
# 3  0.021739  0.010870  0.083333  0.086957  0.188406  0.177536  0.152174
# 4  0.009217  0.003456  0.071429  0.099078  0.130184  0.157834  0.184332
# 5  0.007347  0.032653  0.182041  0.185306  0.186939  0.138776  0.114286
#
#          18    Female      Male   dietary   hygiene    injury  mental_health  \
# 0  0.121715  0.605809  0.394191  1.471369  1.080913  1.596720       1.321577
# 1  0.433766  0.335065  0.664935  1.469091  1.069156  1.373655       1.197619
# 2  0.203288  0.579970  0.420030  1.446637  1.062407  1.329383       1.163677
# 3  0.278986  0.329710  0.670290  1.500725  1.209239  1.568323       1.382246
# 4  0.344470  0.464286  0.535714  1.444240  1.074309  1.284315       1.178571
# ...

# %%
categories = ['dietary_behaviours','hygiene','injury','mental_health','tobacco_use','alcohol_use','drug_use','sexual_behaviours','physical_activity','protective_factors']
categories = [*categories, categories[0]]

cluster_1 = [1.44,1.06,1.14,1.11,1.09,1.04,1.01,1.02,1.60,1.47]
cluster_2 = [1.47,1.08,1.60,1.32,1.16,1.05,1.03,1.04,1.58,1.51]
cluster_3 = [1.45,1.06,1.33,1.16,1.24,1.57,1.06,1.02,1.59,1.53]
cluster_4 = [1.50,1.21,1.57,1.38,1.62,1.68,1.76,1.52,1.57,1.60]
cluster_5 = [1.44,1.07,1.28,1.18,1.13,1.08,1.02,1.69,1.57,1.51]
cluster_6 = [1.47,1.07,1.37,1.20,1.27,1.64,1.07,1.74,1.57,1.56]
cluster_1 = [*cluster_1, cluster_1[0]]
cluster_2 = [*cluster_2, cluster_2[0]]
cluster_3 = [*cluster_3, cluster_3[0]]
cluster_4 = [*cluster_4, cluster_4[0]]
cluster_5 = [*cluster_5, cluster_5[0]]
cluster_6 = [*cluster_6, cluster_6[0]]



fig = go.Figure(
    data=[
        go.Scatterpolar(r=cluster_1, theta=categories, name='cluster 1'),
        go.Scatterpolar(r=cluster_2, theta=categories, name='cluster 2'),
        go.Scatterpolar(r=cluster_3, theta=categories, name='cluster 3'),
        go.Scatterpolar(r=cluster_4, theta=categories, name='cluster 4'),
        go.Scatterpolar(r=cluster_5, theta=categories, name='cluster 5'),
        go.Scatterpolar(r=cluster_6, theta=categories, name='cluster 6'),
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Result of Kmeans with number 6 on mf'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig)
fig.write_image("radar_chart_Kmeans_mf_6.jpg")

# %% [markdown]
# ## K-prototype

# %%
df_ite_kp = pd.read_csv('clustering_result/result_ite_kp.csv')
df_ite_kp.head()
# Out:
#    11  12   13   14   15   16   17   18  Female  Male  dietary  hygiene  \
# 0  17  56  404  450  553  426  373  349    1770   858   3801.4   2803.5
# 1  15   8  115  154  212  308  331  760     586  1317   2788.2   2081.5
#
#         injury  mental_health  tobacco_use  alcohol_use  drug_use  \
# 0  3452.071429    3085.500000  2985.083333  3019.000000  2702.375
# 1  2662.357143    2326.166667  2420.000000  2741.666667  2182.750
#
#    sexual_behaviours  physical_activity  protective_factors
# 0             2801.7            4196.75         3913.333333
# 1             3182.6            2985.00         2948.500000

# %%
df_ite_kp.loc[0] = df_ite_kp.iloc[0]/2628
df_ite_kp.loc[1] = df_ite_kp.iloc[1]/1903
df_ite_kp.head()
# Out:
#          11        12        13        14        15       16        17  \
# 0  0.006469  0.021309  0.153729  0.171233  0.210426  0.16210  0.141933
# 1  0.007882  0.004204  0.060431  0.080925  0.111403  0.16185  0.173936
#
#          18    Female      Male   dietary   hygiene    injury  mental_health  \
# 0  0.132801  0.673516  0.326484  1.446499  1.066781  1.313574       1.174087
# 1  0.399369  0.307935  0.692065  1.465160  1.093799  1.399032       1.222368
#
#    tobacco_use  alcohol_use  drug_use  sexual_behaviours  physical_activity  \
# 0     1.135876     1.148782  1.028301           1.066096           1.596937
# 1     1.271676     1.440708  1.147005           1.672412           1.568576
#
#    protective_factors
# 0            1.489092
# 1            1.549396

# %%
categories = ['dietary_behaviours','hygiene','injury','mental_health','tobacco_use','alcohol_use','drug_use','sexual_behaviours','physical_activity','protective_factors']
categories = [*categories, categories[0]]

cluster_1 = [1.47,1.09,1.40,1.22,1.27,1.44,1.15,1.67,1.57,1.55]
cluster_2 = [1.45,1.07,1.31,1.17,1.14,1.15,1.03,1.07,1.60,1.49]
cluster_1 = [*cluster_1, cluster_1[0]]
cluster_2 = [*cluster_2, cluster_2[0]]



fig = go.Figure(
    data=[
        go.Scatterpolar(r=cluster_1, theta=categories, name='cluster 1'),
        go.Scatterpolar(r=cluster_2, theta=categories, name='cluster 2')
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Result of K prototype with number 2 on ite'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig)
fig.write_image("radar_chart_Kp_ite_2.jpg")

# %%
df_mca_kp = pd.read_csv('clustering_result/result_mca_kp.csv')
df_mca_kp.head()
# Out:
#    11  12   13   14   15   16   17   18  Female  Male  dietary  hygiene  \
# 0  16  56  410  457  559  429  382  358    1822   845   3860.6  2845.25
# 1  16   8  112  151  205  292  314  766     567  1297   2728.4  2041.25
#
#         injury  mental_health  tobacco_use  alcohol_use  drug_use  \
# 0  3502.357143    3135.000000  3030.500000  3047.000000  2737.875
# 1  2599.000000    2276.333333  2369.666667  2696.833333  2139.750
#
#    sexual_behaviours  physical_activity  protective_factors
# 0             2843.8             4257.5         3972.000000
# 1             3132.3             2923.5         2888.833333

# %%
df_mca_kp.loc[0] = df_mca_kp.iloc[0]/2667
df_mca_kp.loc[1] = df_mca_kp.iloc[1]/1864
df_mca_kp.head()
# Out:
#          11        12        13        14        15        16        17  \
# 0  0.005999  0.020997  0.153731  0.171354  0.209599  0.160855  0.143232
# 1  0.008584  0.004292  0.060086  0.081009  0.109979  0.156652  0.168455
#
#          18    Female      Male   dietary   hygiene    injury  mental_health  \
# 0  0.134233  0.683165  0.316835  1.447544  1.066835  1.313220       1.175478
# 1  0.410944  0.304185  0.695815  1.463734  1.095091  1.394313       1.221209
#
#    tobacco_use  alcohol_use  drug_use  sexual_behaviours  physical_activity  \
# 0     1.136295     1.142482  1.026575           1.066292           1.596363
# 1     1.271280     1.446799  1.147935           1.680418           1.568401
#
#    protective_factors
# 0            1.489314
# 1            1.549803

# %%
categories = ['dietary_behaviours','hygiene','injury','mental_health','tobacco_use','alcohol_use','drug_use','sexual_behaviours','physical_activity','protective_factors']
categories = [*categories, categories[0]]

cluster_1 = [1.46,1.10,1.39,1.22,1.27,1.45,1.15,1.68,1.57,1.55]
cluster_2 = [1.45,1.07,1.31,1.18,1.14,1.14,1.03,1.07,1.60,1.49]
cluster_1 = [*cluster_1, cluster_1[0]]
cluster_2 = [*cluster_2, cluster_2[0]]



fig = go.Figure(
    data=[
        go.Scatterpolar(r=cluster_1, theta=categories, name='cluster 1'),
        go.Scatterpolar(r=cluster_2, theta=categories, name='cluster 2')
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Result of K prototype with number 2 on mca'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig)
fig.write_image("radar_chart_Kp_mca_2.jpg")

# %%
df_mf_kp = pd.read_csv('clustering_result/result_mf_kp.csv')
df_mf_kp.head()
# Out:
#    11  12   13   14   15   16   17   18  Female  Male  dietary  hygiene  \
# 0  16  58  417  458  545  432  388  374    1813   875   3889.4  2869.25
# 1  16   8  111  156  208  289  308  747     571  1272   2701.0  2017.00
#
#         injury  mental_health  tobacco_use  alcohol_use  drug_use  \
# 0  3508.142857    3166.000000  3058.833333  3087.666667  2761.750
# 1  2542.571429    2252.666667  2351.916667  2671.750000  2127.125
#
#    sexual_behaviours  physical_activity  protective_factors
# 0             2845.1            4288.75         4008.166667
# 1             3065.1            2890.50         2853.166667

# %%
df_mf_kp.loc[0] = df_mf_kp.iloc[0]/2688
df_mf_kp.loc[1] = df_mf_kp.iloc[1]/1843
df_mf_kp.head()
# Out:
#          11        12        13        14        15        16        17  \
# 0  0.005952  0.021577  0.155134  0.170387  0.202753  0.160714  0.144345
# 1  0.008681  0.004341  0.060228  0.084645  0.112859  0.156810  0.167119
#
#          18    Female      Male   dietary   hygiene    injury  mental_health  \
# 0  0.139137  0.674479  0.325521  1.446949  1.067429  1.305113       1.177827
# 1  0.405317  0.309821  0.690179  1.465545  1.094411  1.379583       1.222283
#
#    tobacco_use  alcohol_use  drug_use  sexual_behaviours  physical_activity  \
# 0     1.137959     1.148686  1.027437           1.058445           1.595517
# 1     1.276135     1.449674  1.154164           1.663104           1.568367
#
#    protective_factors
# 0            1.491133
# 1            1.548110

# %%
categories = ['dietary_behaviours','hygiene','injury','mental_health','tobacco_use','alcohol_use','drug_use','sexual_behaviours','physical_activity','protective_factors']
categories = [*categories, categories[0]]

cluster_1 = [1.47,1.09,1.38,1.22,1.28,1.45,1.15,1.66,1.57,1.55]
cluster_2 = [1.45,1.07,1.31,1.18,1.14,1.15,1.03,1.06,1.60,1.49]
cluster_1 = [*cluster_1, cluster_1[0]]
cluster_2 = [*cluster_2, cluster_2[0]]



fig = go.Figure(
    data=[
        go.Scatterpolar(r=cluster_1, theta=categories, name='cluster 1'),
        go.Scatterpolar(r=cluster_2, theta=categories, name='cluster 2')
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Result of K prototype with number 2 on mf'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig)
fig.write_image("radar_chart_Kp_mf_2.jpg")
